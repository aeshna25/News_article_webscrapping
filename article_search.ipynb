# %%
! pip install requests beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
import json

def get_articles(company: str, site: str) -> dict:
    search_url = f"https://{site}/companies/{company}/"  # Filter for last year
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36"
    }
    print(search_url)
    response = requests.get(search_url, headers=headers)
    if response.status_code != 200:
        return {"error": f"Failed to fetch results. Status code: {response.status_code}"}
    
    soup = BeautifulSoup(response.text, "html.parser")
    articles = []

    for result in soup.select("div.profile-news__items profile-news__items--has-hidden"):
        title_tag = result.select_one("h3 a").text  # Extract title text
        link_tag = result.select_one("h3 a")["href"]
        if title_tag and link_tag:
            articles.append({
                "title": title_tag.text,
                "link": link_tag["href"]
            })

    return {"company": company, "site": site, "articles": articles}

# Example usage
company_name = "Microsoft"
site_name = "forbes.com"

result = get_articles('microsoft', 'www.forbes.com')

# Save result to a JSON file
with open(f"{company_name}_articles.json", "w") as file:
    json.dump(result, file, indent=4)

print(json.dumps(result, indent=4))
# Out:
# https://www.forbes.com/companies/microsoft/

# %%
result
# Out:
# {'company': 'microsoft', 'site': 'www.forbes.com', 'articles': []}

# %%
from bs4 import BeautifulSoup
import requests
def get_articles(company: str, site: str) -> dict:
    url = f"https://{site}/companies/{company}/" #'https://www.forbes.com/companies/microsoft/' 

    headers = {
    "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Version/5.1 Mobile/9B179 Safari/7534.48.3"
    }

   

    response = requests.get(url, headers=headers)

   
    soup = BeautifulSoup(response.content, 'html.parser')
    soup.encode('utf-8')
    # print(response.content)
    urls = soup.find_all(class_ = 'stream-item__title') 
    desc = soup.find_all(class_ = 'stream-item__description') 
    links = soup.find_all(class_ = 'stream-item__text') 
    article_name= []
    article_desp =[]
    link_list =[]
    for url in urls:
        # print(url)
        name=  url.find('h3').text
        article_name.append(name)
        for des in desc:
            desp = des.get_text() 
            article_desp.append(desp)
    # print(article_name[4])
    # print(article_desp[4])
    for link in links:
        lst = link.find("a", class_="stream-item__title long-title")['href']
        link_list.append(lst)
    # print(link_list[4])  
    merged = [
    {"Article name": article_name, "Article description": article_desp, "Article link": link_list} 
    for article_name, article_desp, link_list in zip(article_name, article_desp, link_list)
            ]     
    return merged

# %%
get_articles('microsoft','forbes.com')
# Out:
# [{'Article name': 'FC Barcelona Vs Benfica Champions League Line Up: Flick Goes For Broke',
#   'Article description': 'FC Barcelona head coach Hansi Flick will field his strongest side possible when the Catalans take on Benfica in the Estadio da Luz on Tuesday for a Champions League clash',
#   'Article link': 'https://www.forbes.com/sites/tomsanderson/2025/01/21/fc-barcelona-vs-benfica-champions-league-line-up-flick-goes-for-broke/'},
#  {'Article name': 'Offseason Remains Stunningly Quiet So Far For Pesky San Diego Padres',
#   'Article description': 'The Padres have not made a major move this offseason in their quest to catch the powerful Los Angeles Dodgers.',
#   'Article link': 'https://www.forbes.com/sites/berniepleskoff/2025/01/21/quiet-offseason-wont-help-san-diego-padres-catch-los-angeles-dodgers/'},
#  {'Article name': 'DHS Secretary Abruptly Ends Remote Work; Orders Employees To Return To Office',
# ...

# %%
# https://www.ft.com/search?q=tata&dateRange=now-1y&sort=relevance&isFirstView=false

# %%
url = 'https://www.ft.com/search?q=tata&dateRange=now-1y&sort=relevance&isFirstView=false' #'https://www.forbes.com/companies/microsoft/' 

headers = {
"User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Version/5.1 Mobile/9B179 Safari/7534.48.3"
}
response = requests.get(url, headers=headers)

   
soup = BeautifulSoup(response.content, 'html.parser')
soup.encode('utf-8')
# print(response.content)
urls = soup.find_all(class_ = 'o-teaser__heading') 
desc = soup.find_all(class_ = 'o-teaser__standfirst') 
dates = soup.find_all(class_ = 'o-teaser__timestamp') 
article_name= []
article_desp =[]
article_date =[]
link_list =[]
for url in urls:
    # print(url)
    name=  url.find('a').text
    article_name.append(name)
for des in desc:
    desp = des.get_text() 
    # print(desp)
    article_desp.append(desp)
for date in dates:
    dat = date.get_text() 
    # print(dat)
    article_date.append(dat)
for link in urls:
    lst = link.find("a")['href']
    # print(lst)
    link_list.append(lst)
merged = [
    {"Article name": article_name,'Article date': article_date, "Article description": article_desp, "Article link": link_list} 
    for article_name,article_date, article_desp, link_list in zip(article_name,article_date, article_desp, link_list)
            ] 
merged
# Out:
# [{'Article name': 'Ratan Tata, leading Indian businessman, 1937-2024 ',
#   'Article date': 'October 9, 2024',
#   'Article description': 'Industrialist who led the Tata conglomerate’s acquisition of Jaguar Land Rover and UK steel plants, with mixed results',
#   'Article link': 'https://www.ft.com/content/5a405ffe-e9ef-4ebf-9203-ce2283f6d203'},
#  {'Article name': 'Tata Steel UK losses jump fourfold ',
#   'Article date': 'December 4, 2024',
#   'Article description': 'Indian-owned group takes £1.12bn hit after writing down value of legacy assets',
#   'Article link': 'https://www.ft.com/content/3bb955cc-079c-4545-9d10-ca3a187529a9'},
#  {'Article name': 'Tata ‘very close’ to securing £500mn of state aid for UK’s largest steelmaking plant',
#   'Article date': 'September 10, 2024',
#   'Article description': 'Chair of Indian parent company says talks with the British government are ‘going well’',
# ...

# %%
def get_articles(company: str) -> dict:
    # url = 'https://www.ft.com/search?q=tata&dateRange=now-1y&sort=relevance&isFirstView=false' #'https://www.forbes.com/companies/microsoft/' 
    url = f'https://www.ft.com/search?q={company}&dateRange=now-1y&sort=relevance&isFirstView=false'
    headers = {
    "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Version/5.1 Mobile/9B179 Safari/7534.48.3"
    }
    response = requests.get(url, headers=headers)

    
    soup = BeautifulSoup(response.content, 'html.parser')
    soup.encode('utf-8')
    # print(response.content)
    urls = soup.find_all(class_ = 'o-teaser__heading') 
    desc = soup.find_all(class_ = 'o-teaser__standfirst') 
    dates = soup.find_all(class_ = 'o-teaser__timestamp') 
    article_name= []
    article_desp =[]
    article_date =[]
    link_list =[]
    for url in urls:
        # print(url)
        name=  url.find('a').text
        article_name.append(name)
    for des in desc:
        desp = des.get_text() 
        # print(desp)
        article_desp.append(desp)
    for date in dates:
        dat = date.get_text() 
        # print(dat)
        article_date.append(dat)
    for link in urls:
        lst = link.find("a")['href']
        # print(lst)
        link_list.append(lst)
    merged = [
        {"Article name": article_name,'Article date': article_date, "Article description": article_desp, "Article link": link_list} 
        for article_name,article_date, article_desp, link_list in zip(article_name,article_date, article_desp, link_list)
                ] 
    return merged

# %%
get_articles('zomato')
# Out:
# [{'Article name': 'What to watch in Asia today',
#   'Article date': 'December 29, 2024',
#   'Article description': 'Bank of Japan releases monetary policy minutes, India’s Zomato joins the BSE Sensex and Arcadium shareholders vote on Rio Tinto’s takeover bid. Events...',
#   'Article link': '/content/bdeedf81-1fa5-4197-81a5-cea21db96c56#post-1a1b0611-ae85-4e32-a16d-b197fe7fdd55'},
#  {'Article name': 'Indian food delivery app Swiggy rises in market debut ',
#   'Article date': 'November 10, 2024',
#   'Article description': 'Indian food delivery app Swiggy rose on its stock market debut following its $1.3bn offering last week, but pared back an initial jump amid a broad ma...',
#   'Article link': '/content/679bd348-a441-46a3-ac54-8f3c2f767459#post-c7f55cb4-31b7-4963-bff0-2c1d7425eb22'},
#  {'Article name': 'India is overlooking the climate drag on its economic growth',
#   'Article date': 'November 12, 2024',
# ...
